# %%
import csv, getpass, json, os, time


def parse_tweet_json(tweet):
        # parse json
    try:
        tweet_json = json.loads(tweet)
    except ValueError:
        raise RuntimeError('error parsing json')

    # look for twitter api error msgs
    if 'error' in tweet_json:
        raise RuntimeError('error in downloaded tweet')

    # extract creation date and tweet text
    return [tweet_json['text']]

def get_full_corpus(infile, writer):
    fpr  = open(infile, 'rb')
    lines = fpr.readlines()
    missing_count = 0
    count = 0;
    for line in lines:
        if count%10000==0:
            print "#####################################################################################"

        #    break
        count += 1
        #print line
        # parse tweet
        try: 
            parsed_tweet = parse_tweet_json(line)
            full_row = parsed_tweet
            # character encoding for output
            for i in range(0,len(full_row)):
                full_row[i] = full_row[i].encode("utf-8")
                # write csv row
                writer.writerow( full_row )

        except RuntimeError:
            print '--> bad data in tweet #' + item
            missing_count += 1
        
    # indicate success
    if missing_count == 0:
        print '\nSuccessfully parsed all the tweets!'
    else: 
        print '\nMissing %d of tweets!' % missing_count

def main():
    # set parameters
    outfile = 'full-corpus.csv'
    fpw = open( outfile, 'ab' )

    # open csv output file
    writer = csv.writer( fpw, delimiter=',', quotechar='"', escapechar='\\', quoting=csv.QUOTE_ALL )
    # write header row
    writer.writerow( ['TweetText'] )
    
    # build output corpus
    cache_list = ['cache-0-json','cache-1000000-json','cache-2000000-json', 'cache-3000000-json','cache-4000000-json',
                  'cache-5000000-json','cache-6000000-json','cache-7000000-json','cache-8000000-json',
                  'cache-9000000-json','cache-10000000-json','cache-11000000-json']
    for infile in cache_list:
        get_full_corpus(infile, writer)
    
if __name__ == '__main__':
    main()
# Out:
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# #####################################################################################
# ...
